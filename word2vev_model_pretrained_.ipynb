# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish899999/NLP_preprocesssing/blob/main/word2vev_model_pretrained_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pretrained model

# %%
import gensim.downloader as api

model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model['man'].shape
# Out:
# (300,)

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model['ashish']
# Out:
# array([-4.22363281e-02, -8.30078125e-02, -1.33666992e-02,  1.70898438e-01,
#        -6.98242188e-02,  1.45263672e-02, -1.22680664e-02, -1.14257812e-01,
#         7.91015625e-02, -1.98974609e-02, -1.62109375e-01,  1.30615234e-02,
#        -1.68945312e-01, -1.06445312e-01, -9.42382812e-02,  5.71289062e-02,
#         1.96289062e-01, -1.09863281e-02, -1.84570312e-01, -5.34667969e-02,
#         1.37939453e-02, -3.00292969e-02,  2.92968750e-01,  9.70458984e-03,
#         4.80957031e-02,  1.21582031e-01, -3.39355469e-02,  1.98974609e-02,
#         9.13085938e-02, -2.64892578e-02, -1.47094727e-02, -7.95898438e-02,
#        -1.50756836e-02, -1.97265625e-01, -5.61523438e-02, -1.23535156e-01,
#        -7.91015625e-02,  3.61328125e-02, -3.08837891e-02,  9.86328125e-02,
#        -7.42187500e-02, -7.61718750e-02,  1.10351562e-01,  9.17968750e-02,
#         1.66015625e-02, -2.29492188e-02, -5.55419922e-03, -9.81445312e-02,
# ...

# %%
model.most_similar('women')
# Out:
# [('men', 0.767493724822998),
#  ('Women', 0.7283449769020081),
#  ('womens', 0.6786180734634399),
#  ('girls', 0.6339040398597717),
#  ('females', 0.6240420341491699),
#  ('mothers', 0.6050933599472046),
#  ('ladies', 0.5865179300308228),
#  ('husbands', 0.5705342292785645),
#  ('transwomen', 0.5697940587997437),
#  ('Men', 0.5693342089653015)]

# %%
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('sex')
# Out:
# [('sexual', 0.7694740295410156),
#  ('oral_sex', 0.6738982200622559),
#  ('sexual_intercourse', 0.6690444946289062),
#  ('intercourse', 0.6402736306190491),
#  ('anal_sex', 0.6372366547584534),
#  ('sexual_encounters', 0.6306261420249939),
#  ('Chastity_Bono_announces', 0.6105126738548279),
#  ('prostitution', 0.5989327430725098),
#  ('Sex', 0.5975605845451355),
#  ('masturbation', 0.5959035158157349)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
model.similarity('man','women')
# Out:
# 0.2883053

# %%
model.similarity('man','PHP')
# Out:
# -0.032995153

# %%
model.doesnt_match(['PHP','Java','monkey'])
# Out:
# 'monkey'

# %%
vec=model['king']-model['man']+model['women']
model.most_similar([vec])
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.535493791103363),
#  ('women', 0.5233659148216248),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.4995364248752594),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]
