# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish899999/NLP_preprocesssing/blob/main/kaggle_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
from zipfile import ZipFile
import pandas as pd
from sklearn.model_selection  import train_test_split
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
kaggle_dictionary=json.load(open("kaggle.json"))

# %%
# !kaggle datasets download -d lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# ...
#  78% 20.0M/25.7M [00:01<00:00, 15.9MB/s]
# 100% 25.7M/25.7M [00:01<00:00, 21.2MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/imdb-dataset-of-50k-movie-reviews.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
df=pd.read_csv(r'/content/imdb-dataset-of-50k-movie-reviews.zip')
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # lower casing

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
df['review'][3].lower()
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.<br /><br />ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %%
df['review'].str.lower()
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production. <br /><br />the...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there's a family where a little boy ...
# 4        petter mattei's "love in the time of money" is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i'm going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %%
df['review']=df['review'].str.lower()

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. <br /><br />the...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # remove HTml tags

# %%
# using regular expression

# %%
import re
def remove_html_tags(text):
  pattern=re.compile('<.*?>')
  return pattern.sub(r'',text)

# %%
remove_html_tags(df['review'][3])
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %%
df['review']=df['review'].apply(remove_html_tags)
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # removing url's

# %%
def remove_urls(text):
  pattern=re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'',text)

# %%
text=" heyoo https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews"
remove_urls(text)
# Out:
# ' heyoo '

# %%
df['review']=df['review'].apply(remove_urls)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Remove punctuations

# %%
import string,time
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude=string.punctuation

# %%
def remove_punc(text):
  for char in exclude:
    text=text.replace(char,'')
  return text

# %%
text='hey? are u there'
remove_punc(text)
# Out:
# 'hey are u there'

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df['review']=df['review'].apply(remove_punc)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production the filming tech...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically theres a family where a little boy j...  negative
# 4      petter matteis love in the time of money is a ...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  im going to have to disagree with the previous...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
# this tech is slow

# %%
def remove_punc1(text):
  return text.translate(str.maketrans('','',exclude))

# %%
remove_punc1('her ?....  dsd3*** we')
# Out:
# 'her   dsd3 we'

# %%
df['review']=df['review'].apply(remove_punc1)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production the filming tech...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically theres a family where a little boy j...  negative
# 4      petter matteis love in the time of money is a ...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  im going to have to disagree with the previous...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # chAT WORD TREATMENT

# %% [markdown]
# # spelling correction

# %%
from textblob import TextBlob

# %%
incorrect_text='ceertains condtions '
textBlb=TextBlob(incorrect_text)
textBlb.correct().string
# Out:
# 'certains conditions '

# %% [markdown]
# # removing stop words

# %%
from nltk.corpus import stopwords
import nltk
# !pip install nltk
nltk.download('stopwords')
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
    return ' '.join(filtered_text)

# %%
text='probably my all time favourite web series  , a story of vilage called fulera'
remove_stopwords(text)
# Out:
# 'probably time favourite web series , story vilage called fulera'

# %%
df['review']=df['review'].apply(remove_stopwords)

# %%
df
# Out:
#                                                   review sentiment
# 0      one reviewers mentioned watching 1 oz episode ...  positive
# 1      wonderful little production filming technique ...  positive
# 2      thought wonderful way spend time hot summer we...  positive
# 3      basically theres family little boy jake thinks...  negative
# 4      petter matteis love time money visually stunni...  positive
# ...                                                  ...       ...
# 49995  thought movie right good job wasnt creative or...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  catholic taught parochial elementary schools n...  negative
# 49998  im going disagree previous comment side maltin...  negative
# 49999  one expects star trek movies high art fans exp...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # handling emojis

# %%
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'',text)

# %%
remove_emoji("game is on 🔥🔥")
# Out:
# 'game is on '

# %%
df['review']=df['review'].apply(remove_emoji)
df
# Out:
#                                                   review sentiment
# 0      one reviewers mentioned watching 1 oz episode ...  positive
# 1      wonderful little production filming technique ...  positive
# 2      thought wonderful way spend time hot summer we...  positive
# 3      basically theres family little boy jake thinks...  negative
# 4      petter matteis love time money visually stunni...  positive
# ...                                                  ...       ...
# 49995  thought movie right good job wasnt creative or...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  catholic taught parochial elementary schools n...  negative
# 49998  im going disagree previous comment side maltin...  negative
# 49999  one expects star trek movies high art fans exp...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Tokenization

# %% [markdown]
# 1.using split function

# %%
# word tokenization
sent=' i m going to delhi'
sent.split()
# Out:
# ['i', 'm', 'going', 'to', 'delhi']

# %%
# sentence tokenization
sent='i am going to delhi. i will stay there for 3 days '
sent.split('.')
# Out:
# ['i am going to delhi', ' i will stay there for 3 days ']

# %%
# problem with split function

sent='i m going to delhi!'
sent.split()
# Out:
# ['i', 'm', 'going', 'to', 'delhi!']

# %% [markdown]
# 2.  using regular expression

# %%
import re
sent=' i m going to delhi!'
token=re.findall("[\w']+",sent)
token
# Out:
# ['i', 'm', 'going', 'to', 'delhi']

# %% [markdown]
# 3. NLTK

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sent='i m going to delhi!'
word_tokenize(sent)
# Out:
# ['i', 'm', 'going', 'to', 'delhi', '!']

# %% [markdown]
# spacy- best technique

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
doc1=nlp("we're here to save p@ashsi ")
doc1
# Out:
# we're here to save p@ashsi

# %%
for token in doc1:
  print(token)
# Out:
# we
# 're
# here
# to
# save
# p@ashsi

# %% [markdown]
# stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps= PorterStemmer()
def stem_words(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
sample="walk walks walking  walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
df['review']=df['review'].apply(stem_words)

# %%
df
# Out:
#                                                   review sentiment
# 0      one review mention watch 1 oz episod youll hoo...  positive
# 1      wonder littl product film techniqu unassum old...  positive
# 2      thought wonder way spend time hot summer weeke...  positive
# 3      basic there famili littl boy jake think there ...  negative
# 4      petter mattei love time money visual stun film...  positive
# ...                                                  ...       ...
# 49995  thought movi right good job wasnt creativ orig...  positive
# 49996  bad plot bad dialogu bad act idiot direct anno...  negative
# 49997  cathol taught parochi elementari school nun ta...  negative
# 49998  im go disagre previou comment side maltin one ...  negative
# 49999  one expect star trek movi high art fan expect ...  negative
#
# [50000 rows x 2 columns]

# %%
df
# Out:
#                                                   review sentiment
# 0      one review mention watch 1 oz episod youll hoo...  positive
# 1      wonder littl product film techniqu unassum old...  positive
# 2      thought wonder way spend time hot summer weeke...  positive
# 3      basic there famili littl boy jake think there ...  negative
# 4      petter mattei love time money visual stun film...  positive
# ...                                                  ...       ...
# 49995  thought movi right good job wasnt creativ orig...  positive
# 49996  bad plot bad dialogu bad act idiot direct anno...  negative
# 49997  cathol taught parochi elementari school nun ta...  negative
# 49998  im go disagre previou comment side maltin one ...  negative
# 49999  one expect star trek movi high art fan expect ...  negative
#
# [50000 rows x 2 columns]
